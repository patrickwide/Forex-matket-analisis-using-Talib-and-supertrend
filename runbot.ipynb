# %%
import talib as ta
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-39fbdb69ff19> in <module>
# ----> 1 import talib as ta
#
# C:\ProgramData\Anaconda3\lib\site-packages\talib\__init__.py in <module>
#      50         return wrapper
#      51
# ---> 52 from ._ta_lib import (
#      53     _ta_initialize, _ta_shutdown, MA_Type, __ta_version__,
#      54     _ta_set_unstable_period as set_unstable_period,
#
# talib\_ta_lib.pyx in init talib._ta_lib()
#
# ValueError: numpy.ndarray size changed, may indicate binary incompatibility. Expected 88 from C header, got 80 from PyObject

# %%
! pip uninstall numpy
# Out:
# ^C

# %%
# !conda install -y -c conda-forge numpy
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38haa244fe_0         3.1 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.10.1-py38haa95532_1 --> conda-forge::conda-4.10.3-py38haa244fe_0
#
#
#
# ...
#
# conda-4.10.3         | 3.1 MB    |            |   0%
# conda-4.10.3         | 3.1 MB    |            |   1%
# ...

# %%
import functions
from functions import run

# %%
import time
import functions
import functions
from functions import run

print(run())

print('hello world')
time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-204-caebba08f6a5> in <module>
#       2 import functions
#       3 import functions
# ----> 4 from functions import run
#       5
#       6 print(run())
#
# ImportError: cannot import name 'run' from 'functions' (C:\Users\user\Desktop\workshop\functions.py)
